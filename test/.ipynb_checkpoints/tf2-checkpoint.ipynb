# %%
import tensorflow as tf
import numpy as np
import cv2
import time
from matplotlib import pyplot as plt
from itertools import product
from math import sqrt

# %%
class FeaturePyramidNeck(tf.keras.layers.Layer):
    """
        Creating the backbone component of feature Pyramid Network
        Arguments:
            num_fpn_filters
    """

    def __init__(self, num_fpn_filters):
        super(FeaturePyramidNeck, self).__init__()
        self.upSample = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation='bilinear')

        # no Relu for downsample layer
        self.downSample1 = tf.keras.layers.Conv2D(num_fpn_filters, (3, 3), 2, padding="same",
                                                  kernel_initializer=tf.keras.initializers.glorot_uniform())

        self.downSample2 = tf.keras.layers.Conv2D(num_fpn_filters, (3, 3), 2, padding="same",
                                                  kernel_initializer=tf.keras.initializers.glorot_uniform())

        self.lateralCov1 = tf.keras.layers.Conv2D(num_fpn_filters, (1, 1), 1, padding="same",
                                                  kernel_initializer=tf.keras.initializers.glorot_uniform())
        self.lateralCov2 = tf.keras.layers.Conv2D(num_fpn_filters, (1, 1), 1, padding="same",
                                                  kernel_initializer=tf.keras.initializers.glorot_uniform())
        self.lateralCov3 = tf.keras.layers.Conv2D(num_fpn_filters, (1, 1), 1, padding="same",
                                                  kernel_initializer=tf.keras.initializers.glorot_uniform())

        # predict layer for FPN
        self.predictP5 = tf.keras.layers.Conv2D(num_fpn_filters, (3, 3), 1, padding="same",
                                                kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                                activation="relu")
        self.predictP4 = tf.keras.layers.Conv2D(num_fpn_filters, (3, 3), 1, padding="same",
                                                kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                                activation="relu")
        self.predictP3 = tf.keras.layers.Conv2D(num_fpn_filters, (3, 3), 1, padding="same",
                                                kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                                activation="relu")

    def call(self, c3, c4, c5):
        # lateral conv for c3 c4 c5
        p5 = self.lateralCov1(c5)
        p4 = self._crop_and_add(self.upSample(p5), self.lateralCov2(c4))
        p3 = self._crop_and_add(self.upSample(p4), self.lateralCov3(c3))
        print("p3: ", p3.shape)

        # smooth pred layer for p3, p4, p5
        p3 = self.predictP3(p3)
        p4 = self.predictP4(p4)
        p5 = self.predictP5(p5)

        # downsample conv to get p6, p7
        p6 = self.downSample1(p5)
        p7 = self.downSample2(p6)

        return [p3, p4, p5, p6, p7]

    def _crop_and_add(self, x1, x2):
        """
        for p4, c4; p3, c3 to concatenate with matched shape
        https://tf-unet.readthedocs.io/en/latest/_modules/tf_unet/layers.html
        """
        x1_shape = x1.shape
        x2_shape = x2.shape
        offsets = [0, (x1_shape[1] - x2_shape[1]) // 2, (x1_shape[2] - x2_shape[2]) // 2, 0]
        size = [-1, x2_shape[1], x2_shape[2], -1]
        x1_crop = tf.slice(x1, offsets, size)
        return tf.add(x1_crop, x2)

# %%
out = ['conv3_block4_out', 'conv4_block6_out', 'conv5_block3_out']
base_model = tf.keras.applications.ResNet50(input_shape=(360, 1205, 3), #input_shape=(360, 1205, 3),
                                                    include_top=False,
                                                    layers=tf.keras.layers,
                                                    weights='imagenet')
backbone_resnet = tf.keras.Model(inputs=base_model.input,
                                              outputs=[base_model.get_layer(x).output for x in out])

backbone_fpn = FeaturePyramidNeck(256)

# %%
backbone_resnet.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 360, 1205, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 366, 1211, 3) 0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 180, 603, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 180, 603, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 180, 603, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 182, 605, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 90, 302, 64)  0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 90, 302, 64)  4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 90, 302, 64)  256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 90, 302, 64)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 90, 302, 64)  36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 90, 302, 64)  256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 90, 302, 64)  0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 90, 302, 256) 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 90, 302, 256) 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 90, 302, 256) 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 90, 302, 256) 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 90, 302, 256) 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 90, 302, 256) 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 90, 302, 64)  16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 90, 302, 64)  256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 90, 302, 64)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 90, 302, 64)  36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 90, 302, 64)  256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 90, 302, 64)  0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 90, 302, 256) 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 90, 302, 256) 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 90, 302, 256) 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 90, 302, 256) 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 90, 302, 64)  16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 90, 302, 64)  256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 90, 302, 64)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 90, 302, 64)  36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 90, 302, 64)  256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 90, 302, 64)  0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 90, 302, 256) 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 90, 302, 256) 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 90, 302, 256) 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 90, 302, 256) 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 45, 151, 128) 32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 45, 151, 128) 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 45, 151, 128) 147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 45, 151, 128) 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 45, 151, 512) 131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 45, 151, 512) 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 45, 151, 512) 2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 45, 151, 512) 2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 45, 151, 512) 0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 45, 151, 512) 0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 45, 151, 128) 65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 45, 151, 128) 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 45, 151, 128) 147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 45, 151, 128) 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 45, 151, 512) 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 45, 151, 512) 2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 45, 151, 512) 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 45, 151, 512) 0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 45, 151, 128) 65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 45, 151, 128) 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 45, 151, 128) 147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 45, 151, 128) 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 45, 151, 512) 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 45, 151, 512) 2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 45, 151, 512) 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 45, 151, 512) 0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 45, 151, 128) 65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 45, 151, 128) 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 45, 151, 128) 147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 45, 151, 128) 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 45, 151, 128) 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 45, 151, 512) 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 45, 151, 512) 2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 45, 151, 512) 0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 45, 151, 512) 0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 23, 76, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 23, 76, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 23, 76, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 23, 76, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 23, 76, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 23, 76, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 23, 76, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 23, 76, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 23, 76, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 23, 76, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 23, 76, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 23, 76, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 23, 76, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 23, 76, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 23, 76, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 23, 76, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 23, 76, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 23, 76, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 23, 76, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 23, 76, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 23, 76, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 23, 76, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 23, 76, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 23, 76, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 23, 76, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 23, 76, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 23, 76, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 23, 76, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 23, 76, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 23, 76, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 23, 76, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 23, 76, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 23, 76, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 23, 76, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 23, 76, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 23, 76, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 23, 76, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 23, 76, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 23, 76, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 23, 76, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 23, 76, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 23, 76, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 23, 76, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 23, 76, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 23, 76, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 23, 76, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 23, 76, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 23, 76, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 23, 76, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 23, 76, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 23, 76, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 12, 38, 512)  524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 12, 38, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 12, 38, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 12, 38, 512)  2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 12, 38, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 12, 38, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 12, 38, 2048) 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 12, 38, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 12, 38, 2048) 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 12, 38, 2048) 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 12, 38, 2048) 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 12, 38, 2048) 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 12, 38, 512)  1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 12, 38, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 12, 38, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 12, 38, 512)  2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 12, 38, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 12, 38, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 12, 38, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 12, 38, 2048) 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 12, 38, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 12, 38, 2048) 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 12, 38, 512)  1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 12, 38, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 12, 38, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 12, 38, 512)  2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 12, 38, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 12, 38, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 12, 38, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 12, 38, 2048) 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 12, 38, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 12, 38, 2048) 0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
feature_map_size = np.array([list(base_model.get_layer(x).output.shape[1:3]) for x in out])

# %%
out_height_p6 = np.ceil((feature_map_size[-1, 0]).astype(np.float32) / float(2))
out_width_p6  = np.ceil((feature_map_size[-1, 1]).astype(np.float32) / float(2))

# %%
out_height_p7 = np.ceil(out_height_p6 / float(2))
out_width_p7  = np.ceil(out_width_p6/ float(2))

# %%
feature_map_size = np.concatenate((feature_map_size, [[out_height_p6, out_width_p6], [out_height_p7, out_width_p7]]), axis=0)

# %%
feature_map_size
# Out:
# array([[ 45., 151.],
#        [ 23.,  76.],
#        [ 12.,  38.],
#        [  6.,  19.],
#        [  3.,  10.]])

# %%
aspect_ratio=[1, 0.5, 2]
scale=[24, 48, 96, 192, 384]
img_h = 360
img_w = 1205

prior_boxes = []
num_anchors = []
for idx, f_size in enumerate(feature_map_size):
    # print("Create priors for f_size:%s", f_size)
    count_anchor = 0
    for j, i in product(range(int(f_size[0])), range(int(f_size[1]))):
        f_k_h = img_h / (f_size[0] + 1)
        f_k_w = img_w / (f_size[1] + 1)
        x = f_k_w * (i + 1)
        y = f_k_h * (j + 1)
        for ars in aspect_ratio:
            a = sqrt(ars)
            w = scale[idx] * a
            h = scale[idx] / a
            prior_boxes += [x - (w / 2), y - (h / 2), x + (w / 2), y + (h / 2)]
            count_anchor += 1
    num_anchors.append(count_anchor)

# %%
num_anchors
# Out:
# [20385, 5244, 1368, 342, 90]

# %%
class TfExampleDecoder(object):
    def __init__(self):
        self._keys_to_features = {
            'image/height': tf.io.FixedLenFeature([], dtype=tf.int64),
            'image/width': tf.io.FixedLenFeature([], dtype=tf.int64),
            'image/encoded': tf.io.FixedLenFeature([], dtype=tf.string),
            'image/object/bbox/xmin': tf.io.VarLenFeature(dtype=tf.float32),
            'image/object/bbox/xmax': tf.io.VarLenFeature(dtype=tf.float32),
            'image/object/bbox/ymin': tf.io.VarLenFeature(dtype=tf.float32),
            'image/object/bbox/ymax': tf.io.VarLenFeature(dtype=tf.float32),
            'image/object/class/label': tf.io.VarLenFeature(dtype=tf.int64),
            'image/object/is_crowd': tf.io.VarLenFeature(dtype=tf.int64),
            'image/object/mask': tf.io.VarLenFeature(dtype=tf.string),
        }

    def _decode_image(self, parsed_tensors):
        image = tf.io.decode_jpeg(parsed_tensors['image/encoded'])
        image.set_shape([None, None, 3])
        return image

    def _decode_boxes(self, parsed_tensors):
        # denormalize the box here
        xmin = parsed_tensors['image/object/bbox/xmin']
        ymin = parsed_tensors['image/object/bbox/ymin']
        xmax = parsed_tensors['image/object/bbox/xmax']
        ymax = parsed_tensors['image/object/bbox/ymax']
        return tf.stack([ymin, xmin, ymax, xmax], axis=-1)

    def _decode_masks(self, parsed_tensors):
        def _decode_png_mask(png_bytes):
            mask = tf.squeeze(
                tf.io.decode_png(png_bytes, channels=1, dtype=tf.uint8), axis=-1)
            mask = tf.cast(mask, dtype=tf.float32)
            mask.set_shape([None, None])
            return mask

        height = parsed_tensors['image/height']
        width = parsed_tensors['image/width']
        masks = parsed_tensors['image/object/mask']
        return tf.cond(
            pred=tf.greater(tf.size(input=masks), 0),
            true_fn=lambda: tf.map_fn(_decode_png_mask, masks, dtype=tf.float32),
            false_fn=lambda: tf.zeros([0, height, width], dtype=tf.float32))

    def decode(self, serialized_example):
        parsed_tensors = tf.io.parse_single_example(
            serialized=serialized_example, features=self._keys_to_features
        )

        for k in parsed_tensors:
            if isinstance(parsed_tensors[k], tf.SparseTensor):
                if parsed_tensors[k].dtype == tf.string:
                    parsed_tensors[k] = tf.sparse.to_dense(
                        parsed_tensors[k], default_value=""
                    )
                else:
                    parsed_tensors[k] = tf.sparse.to_dense(
                        parsed_tensors[k], default_value=0)

        image = self._decode_image(parsed_tensors)
        boxes = self._decode_boxes(parsed_tensors)
        masks = self._decode_masks(parsed_tensors)
        is_crowds = tf.cond(
            tf.greater(tf.shape(parsed_tensors['image/object/is_crowd']), 0),
            lambda: tf.cast(parsed_tensors['image/object/is_crowd'], dtype=tf.bool),
            lambda: tf.zeros_like(parsed_tensors['image/object/class/label'], dtype=tf.bool))

        decoded_tensors = {
            'image': image,
            'height': parsed_tensors['image/height'],
            'width': parsed_tensors['image/width'],
            'gt_classes': parsed_tensors['image/object/class/label'],
            'gt_is_crowd': is_crowds,
            'gt_bboxes': boxes,
            'gt_masks': masks
        }

        return decoded_tensors

# %%
_example_decoder = TfExampleDecoder()
trRawDataset = tf.data.TFRecordDataset("/home/deploy/ved/data/train.record")
dsTrain = trRawDataset.map(_example_decoder.decode)

# %%
dsTrain
# Out:
# <MapDataset shapes: {image: (None, None, 3), height: (), width: (), gt_classes: (None,), gt_is_crowd: (None,), gt_bboxes: (None, 4), gt_masks: (None, None, None)}, types: {image: tf.uint8, height: tf.int64, width: tf.int64, gt_classes: tf.int64, gt_is_crowd: tf.bool, gt_bboxes: tf.float32, gt_masks: tf.float32}>

# %%
for parsed_record in dsTrain.take(3):
    img_test = parsed_record['image'].numpy()

# %%
from matplotlib import pyplot as plt
plt.imshow(img_test)

# %%
from itertools import product
from math import sqrt

def make_priors(img_size_h, img_size_w, feature_map_size, aspect_ratio, scale):
    """
    Create anchor boxes for each feature maps in [x, y, w, h], (x, y) is the center of anchor
    :param feature_map_size:
    :param img_size:
    :param aspect_ratio:
    :param scale:
    :return:
    """
    prior_boxes = []
    num_anchors = 0
    for idx, f_size in enumerate(feature_map_size):
        # print("Create priors for f_size:%s", f_size)
        count_anchor = 0
        for j, i in product(range(int(f_size[0])), range(int(f_size[1]))):
            # i,j are pixels values in feature map
            # + 0.5 because priors are in center
            x = (i + 0.5) / f_size[1] # normalize the pixel values
            y = (j + 0.5) / f_size[0]
            for ars in aspect_ratio:
                a = sqrt(ars)
                w = scale[idx] * a / img_size_w # normalize the width value
                h = scale[idx] / a / img_size_h
                # directly use point form here => [cx, cy, w, h]
                prior_boxes += [x, y, w, h]
            count_anchor += 1
        num_anchors += count_anchor
    output = tf.reshape(tf.convert_to_tensor(prior_boxes), [-1, 4])
    output = tf.cast(output, tf.float32)
    return num_anchors, output

# %%
class Yolact(tf.keras.Model):
    """
        Creating the YOLCAT Architecture
        Arguments:

    """

    def __init__(self, img_h, img_w, fpn_channels, num_class, num_mask, aspect_ratio, scales):
        super(Yolact, self).__init__()
        out = ['conv3_block4_out', 'conv4_block6_out', 'conv5_block3_out']
        # use pre-trained ResNet50
        # Todo figure out how pre-trained can be train again
        base_model = tf.keras.applications.ResNet50(input_shape=(img_h, img_w, 3),
                                                    include_top=False,
                                                    layers=tf.keras.layers,
                                                    weights='imagenet')
        # extract certain feature maps for FPN
        self.backbone_resnet = tf.keras.Model(inputs=base_model.input,
                                              outputs=[base_model.get_layer(x).output for x in out])
        
        # Calculating feature map size
        # https://stackoverflow.com/a/44242277/4582711
        # https://github.com/tensorflow/tensorflow/issues/4297#issuecomment-246080982
        self.feature_map_size = np.array([list(base_model.get_layer(x).output.shape[1:3]) for x in out])
        out_height_p6 = np.ceil((self.feature_map_size[-1, 0]).astype(np.float32) / float(2))
        out_width_p6  = np.ceil((self.feature_map_size[-1, 1]).astype(np.float32) / float(2))
        out_height_p7 = np.ceil(out_height_p6 / float(2))
        out_width_p7  = np.ceil(out_width_p6/ float(2))
        self.feature_map_size = np.concatenate((self.feature_map_size, [[out_height_p6, out_width_p6], [out_height_p7, out_width_p7]]), axis=0)
        self.protonet_out_size = self.feature_map_size[0]*2 # Only one upsampling on p3 

        self.backbone_fpn = FeaturePyramidNeck(fpn_channels)
        self.protonet = ProtoNet(num_mask)

        # semantic segmentation branch to boost feature richness
        self.semantic_segmentation = tf.keras.layers.Conv2D(num_class, (1, 1), 1, padding="same",
                                                            kernel_initializer=tf.keras.initializers.glorot_uniform())

        self.num_anchor, self.priors = make_priors(img_h, img_w, self.feature_map_size, aspect_ratio, scales)
#         print("prior shape:", self.priors.shape)
#         print("num anchor per feature map: ", self.num_anchor)

        # shared prediction head
        self.predictionHead = PredictionModule(256, len(aspect_ratio), num_class, num_mask)

    def set_bn(self, mode='train'):
        if mode == 'train':
            for layer in self.backbone_resnet.layers:
                if isinstance(layer, tf.keras.layers.BatchNormalization):
                    layer.trainable = False
        else:
            for layer in self.backbone_resnet.layers:
                if isinstance(layer, tf.keras.layers.BatchNormalization):
                    layer.trainable = True


    @tf.function(input_signature=[tf.TensorSpec([None, None, None, 3], tf.uint8)])
    def __call__(self, inputs):
        # backbone(ResNet + FPN)
        # tf.print("inputs max: ", tf.reduce_max(tf.reshape(inputs[0], [-1])))
        c3, c4, c5 = self.backbone_resnet(inputs)
        # tf.print("c3 max: ", tf.reduce_max(tf.reshape(c3, [-1])))
        # print("c3: ", c3.shape)
        # print("c4: ", c4.shape)
        # print("c5: ", c5.shape)
        fpn_out = self.backbone_fpn(c3, c4, c5)

        # Protonet branch
        p3 = fpn_out[0]
        protonet_out = self.protonet(p3)
        # print("protonet: ", protonet_out.shape)

        # semantic segmentation branch
        seg = self.semantic_segmentation(p3)

        
        # Prediction Head branch
#         pred_cls_p3, pred_offset_p3, pred_coef_p3 = self.predictionHead(fpn_out[0])
#         pred_cls_p4, pred_offset_p4, pred_coef_p4 = self.predictionHead(fpn_out[1])
#         pred_cls_p5, pred_offset_p5, pred_coef_p5 = self.predictionHead(fpn_out[2])
#         pred_cls_p6, pred_offset_p6, pred_coef_p6 = self.predictionHead(fpn_out[3])
#         pred_cls_p7, pred_offset_p7, pred_coef_p7 = self.predictionHead(fpn_out[4])
        
        pred_cls = []
        pred_offset = []
        pred_mask_coef = []

        # all output from FPN use same prediction head
        for f_map in fpn_out:
            cls, offset, coef = self.predictionHead(f_map)
            pred_cls.append(cls)
            pred_offset.append(offset)
            pred_mask_coef.append(coef)
        
        pred_cls = tf.concat(pred_cls, axis=1)
        pred_offset = tf.concat(pred_offset, axis=1)
        pred_mask_coef = tf.concat(pred_mask_coef, axis=1)
            
#         pred_cls = tf.concat([pred_cls_p3, pred_cls_p4, pred_cls_p5, pred_cls_p6, pred_cls_p7], axis=1)
#         pred_offset = tf.concat([pred_offset_p3, pred_offset_p4, pred_offset_p5, pred_offset_p6, pred_offset_p7], axis=1)
#         pred_mask_coef = tf.concat([pred_coef_p3, pred_coef_p4, pred_coef_p5, pred_coef_p6, pred_coef_p7], axis=1)

        pred = {
            'pred_cls': pred_cls,
            'pred_offset': pred_offset,
            'pred_mask_coef': pred_mask_coef,
            'proto_out': protonet_out,
            'seg': seg,
            'priors': self.priors
        }

        return pred

# %%
class PredictionModule(tf.keras.layers.Layer):

    def __init__(self, out_channels, num_anchors, num_class, num_mask):
        super(PredictionModule, self).__init__()
        self.num_anchors = num_anchors
        self.num_class = num_class
        self.num_mask = num_mask

        self.Conv = tf.keras.layers.Conv2D(out_channels, (3, 3), 1, padding="same",
                                           kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                           activation="relu")

        self.classConv = tf.keras.layers.Conv2D(self.num_class * self.num_anchors, (3, 3), 1, padding="same",
                                                kernel_initializer=tf.keras.initializers.glorot_uniform())

        self.boxConv = tf.keras.layers.Conv2D(4 * self.num_anchors, (3, 3), 1, padding="same",
                                              kernel_initializer=tf.keras.initializers.glorot_uniform())

        # activation of mask coef is tanh
        self.maskConv = tf.keras.layers.Conv2D(self.num_mask * self.num_anchors, (3, 3), 1, padding="same",
                                               kernel_initializer=tf.keras.initializers.glorot_uniform())

    def call(self, p):
        p = self.Conv(p)

        pred_class = self.classConv(p)
        pred_box = self.boxConv(p)
        pred_mask = self.maskConv(p)

        # reshape the prediction head result for following loss calculation
        pred_class = tf.reshape(pred_class, [tf.shape(pred_class)[0], -1, self.num_class])
        pred_box = tf.reshape(pred_box, [tf.shape(pred_box)[0], -1, 4])
        pred_mask = tf.reshape(pred_mask, [tf.shape(pred_mask)[0], -1, self.num_mask])

        # add activation for conf and mask coef
        pred_mask = tf.keras.activations.tanh(pred_mask)

        return pred_class, pred_box, pred_mask

# %%
class ProtoNet(tf.keras.layers.Layer):
    """
        Creating the component of ProtoNet
        Arguments:
            num_prototype
    """

    def __init__(self, num_prototype):
        super(ProtoNet, self).__init__()
        self.Conv1 = tf.keras.layers.Conv2D(256, (3, 3), 1, padding="same",
                                            kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                            activation="relu")
        self.Conv2 = tf.keras.layers.Conv2D(256, (3, 3), 1, padding="same",
                                            kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                            activation="relu")
        self.Conv3 = tf.keras.layers.Conv2D(256, (3, 3), 1, padding="same",
                                            kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                            activation="relu")
        self.upSampling = tf.keras.layers.UpSampling2D(size=(2, 2), interpolation='bilinear')
        self.Conv4 = tf.keras.layers.Conv2D(256, (3, 3), 1, padding="same",
                                            kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                            activation="relu")

        self.finalConv = tf.keras.layers.Conv2D(num_prototype, (3, 3), 1, padding="same",
                                                kernel_initializer=tf.keras.initializers.glorot_uniform(),
                                                activation='relu')

    def call(self, p3):
        # (3,3) convolution * 3
        proto = self.Conv1(p3)
        proto = self.Conv2(proto)
        proto = self.Conv3(proto)

        # upsampling + convolution
        proto = self.upSampling(proto)
        proto = self.Conv4(proto)

        # final convolution
        proto = self.finalConv(proto)
        return proto

# %%
model = Yolact(img_h=360, 
              img_w=1205,
              fpn_channels=256,
              num_class=82,
              num_mask=32,
              aspect_ratio=[1.81, 0.86, 0.78],
              scales=[24, 48, 96, 130, 192])

# %%
def add_weight_decay(model, weight_decay):
	if (weight_decay is None) or (weight_decay == 0.0):
		return

	# recursion inside the model
	def add_decay_loss(m, factor):
		if isinstance(m, tf.keras.Model):
			for layer in m.layers:
				add_decay_loss(layer, factor)
		else:
			for param in m.trainable_weights:
				with tf.keras.backend.name_scope('weight_regularizer'):
					regularizer = lambda: tf.keras.regularizers.l2(factor)(param)
					m.add_loss(regularizer)

	# weight decay and l2 regularization differs by a factor of 2
	add_decay_loss(model, weight_decay/2.0)
	return

# %%
# TODO: try this
# https://stackoverflow.com/a/61529570/4582711
l2 = tf.keras.regularizers.l2(1e-4)
for layer in model.layers:
    # if hasattr(layer, 'kernel'):
    # or
    # If you want to apply just on Conv
    if isinstance(layer, tf.keras.layers.Conv2D):
        model.add_loss(lambda layer=layer: l2(layer.kernel))

# %%
# TODO: try this
# https://github.com/tensorflow/tensorflow/issues/33635#issuecomment-545390083
model = tf.keras.applications.ResNet50()
for layer in model.layers:
    if hasattr(layer, 'kernel_regularizer'):
        setattr(layer, 'kernel_regularizer', tf.keras.regularizers.l2(l=1e-5))
        
for layer in model.layers:
    if hasattr(layer, 'kernel_regularizer'):
        assert getattr(layer, 'kernel_regularizer').l2 == np.array([1e-5], dtype='float32')
        
assert model.losses == []
model.save_weights('resnet50.h5', save_format='h5')

new_model = tf.keras.models.model_from_json(model.to_json())
# new_model would have random weights
new_model.load_weights('resnet50.h5')
assert new_model.losses != [] #works fine

# %%
add_weight_decay(model, 5 * 1e-4)

# %%
call_output = model.__call__.get_concrete_function(tf.TensorSpec([None, None, None, 3], tf.uint8))
# Out:
# p3:  (None, 45, 151, 256)
# p3:  (None, 45, 151, 256)

# %%
tf.saved_model.save(model, './saved_model', signatures={'serving_default': call_output})
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <__main__.Yolact object at 0x7f9888b0f5c0>, because it is not built.
# WARNING:tensorflow:From /home/deploy/.local/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./saved_model/assets

# %%
# loaded = tf.saved_model.load('./saved_model')
loaded = tf.saved_model.load('/home/deploy/ved/YOLACT/saved_models/saved_model_4.0358458')

# %%
print(list(loaded.signatures.keys()))  # ["serving_default"]
# Out:
# ['serving_default']

# %%
loaded.signatures['serving_default'].structured_outputs
# Out:
# {'pred_cls': TensorSpec(shape=(None, None, 2), dtype=tf.float32, name='pred_cls'),
#  'pred_mask_coef': TensorSpec(shape=(None, None, 32), dtype=tf.float32, name='pred_mask_coef'),
#  'pred_offset': TensorSpec(shape=(None, None, 4), dtype=tf.float32, name='pred_offset'),
#  'priors': TensorSpec(shape=(27429, 4), dtype=tf.float64, name='priors'),
#  'proto_out': TensorSpec(shape=(None, 90, 302, 32), dtype=tf.float32, name='proto_out'),
#  'seg': TensorSpec(shape=(None, 45, 151, 2), dtype=tf.float32, name='seg')}

# %% [markdown]
# # Inferencing

# %%
img = cv2.imread('test.jpg')
img = cv2.resize(img, (1205, 360))
print(img.shape)
img = img.astype(np.float32, copy=False)
infer = loaded.signatures['serving_default']

@tf.function
def forward(x):
    return infer(x)
# Out:
# (360, 1205, 3)

# %%
img = cv2.resize(img_test, (1205, 360))
img = img.astype(np.float32, copy=False)

# %%
net_outs = forward(img[None, ...])

# %%
net_outs.keys()
# Out:
# dict_keys(['pred_cls', 'pred_offset', 'pred_mask_coef', 'seg', 'priors', 'proto_out'])

# %%
def _decode(box_p, priors, include_variances=False):
    # https://github.com/feiyuhuahuo/Yolact_minimal/blob/9299a0cf346e455d672fadd796ac748871ba85e4/utils/box_utils.py#L151
    """
    Decode predicted bbox coordinates using the scheme
    employed at https://lilianweng.github.io/lil-log/2017/12/31/object-recognition-for-dummies-part-3.html
        b_x = prior_w*loc_x + prior_x
        b_y = prior_h*loc_y + prior_y
        b_w = prior_w * exp(loc_w)
        b_h = prior_h * exp(loc_h)
    
    Note that loc is inputed as [c_x, x_y, w, h]
    while priors are inputed as [c_x, c_y, w, h] where each coordinate
    is relative to size of the image.
    
    Also note that prior_x and prior_y are center coordinates.
    """
    variances = [0.1, 0.2]
    box_p = tf.cast(box_p, tf.float32)
    priors = tf.cast(priors, tf.float32)
    if include_variances:
        b_x_y = priors[:, :2] + box_p[:, :2] * priors[:, 2:]* variances[0]
        b_w_h = priors[:, 2:] * tf.math.exp(box_p[:, 2:]* variances[1])
    else:
        b_x_y = priors[:, :2] + box_p[:, :2] * priors[:, 2:]
        b_w_h = priors[:, 2:] * tf.math.exp(box_p[:, 2:])
    
    boxes = tf.concat([b_x_y, b_w_h], axis=1)
    
    # [x_min, y_min, x_max, y_max]
    boxes = tf.concat([boxes[:, :2] - boxes[:, 2:] / 2, boxes[:, 2:] / 2 + boxes[:, :2]], axis=1)
    
    # [y_min, x_min, y_max, x_max]
    return tf.transpose(tf.stack([boxes[:, 1], boxes[:, 0],boxes[:, 3], boxes[:, 2]]))

# %%
def _traditional_nms(boxes, masks, scores, iou_threshold=0.5, conf_thresh=0.05, score_threshold=0.3, max_class_output_size=100, max_output_size=300, soft_nms_sigma=0.5):
    num_classes = scores.shape[0]

    box_lst = []
    mask_lst = []
    cls_lst = []
    scr_lst = []

    for _cls in range(num_classes):
        cls_scores = scores[_cls, :]
        selected_indices, selected_scores = tf.image.non_max_suppression_with_scores(
            boxes, 
            cls_scores, 
            max_output_size=max_class_output_size, 
            iou_threshold=iou_threshold, 
            score_threshold=score_threshold,
            soft_nms_sigma=soft_nms_sigma)
        
        box_lst.append(tf.squeeze(tf.gather(boxes, selected_indices)))
        mask_lst.append(tf.squeeze(tf.gather(masks, selected_indices)))
        cls_lst.append(selected_indices * 0 + _cls)
        scr_lst.append(tf.squeeze(tf.gather(cls_scores, selected_indices)))

    boxes = tf.concat(box_lst, axis=0)
    masks = tf.concat(mask_lst, axis=0)
    classes = tf.concat(cls_lst, axis=0)
    scores = tf.concat(scr_lst, axis=0)

    _ids = tf.argsort(scores)
    scores = tf.gather(scores, _ids)[:max_output_size]
    boxes = tf.gather(boxes, _ids)[:max_output_size]
    masks = tf.gather(masks, _ids)[:max_output_size]
    classes = tf.gather(classes, _ids)[:max_output_size]

    return boxes, masks, classes, scores

# %%
def _sanitize_coordinates(_x1, _x2, img_size: int, padding: int = 0):
    """
    Sanitizes the input coordinates so that x1 < x2, x1 != x2, x1 >= 0, and x2 <= image_size.
    Also converts from relative to absolute coordinates and casts the results to long tensors.
    Warning: this does things in-place behind the scenes so copy if necessary.
    """
    x1 = tf.math.minimum(_x1, _x2)
    x2 = tf.math.maximum(_x1, _x2)
    x1 = tf.clip_by_value(x1 - padding, clip_value_min=0, clip_value_max=img_size)
    x2 = tf.clip_by_value(x2 + padding, clip_value_min=0, clip_value_max=img_size)

    # Normalize the coordinates
    return x1/img_size, x2/img_size

# %%
def _crop_and_normalize(masks, boxes, padding: int = 1, crop_size=(30,30)):
    """
    "Crop" predicted masks by zeroing out everything not in the predicted bbox.
    Args:
        - masks should be a size [h, w, n] tensor of masks
        - boxes should be a size [n, 4] tensor of bbox coords in relative point form
    """
    h, w, n = masks.shape
    x1, x2 = _sanitize_coordinates(boxes[:, 1], boxes[:, 3], w, padding)
    y1, y2 = _sanitize_coordinates(boxes[:, 0], boxes[:, 2], h, padding)

    # Making adjustments for tf.image.crop_and_resize
    masks = tf.transpose(masks, (2,0,1))
    masks = tf.expand_dims(masks, axis=-1)
    boxes = tf.stack((y1, x1, y2, x2), axis=1)
    box_indices = tf.range(masks.shape[0])

    masks = tf.squeeze(tf.image.crop_and_resize(masks, boxes, box_indices, crop_size))

    return boxes, masks

# %%
def post_process(net_outs, trad_nms=True):
    box_p = tf.squeeze(net_outs['pred_offset'])  # [27429, 4]
    class_p = tf.squeeze(net_outs['pred_cls'])  # [27429, 2]
    coef_p = tf.squeeze(net_outs['pred_mask_coef'])  # [27429, 32]
    anchors = tf.squeeze(net_outs['priors'])  # [27429, 4]
    proto_p = tf.squeeze(net_outs['proto_out'])  # [90, 302, 32]

    class_p = tf.transpose(class_p)  # [2, 27429]
    box_decode = _decode(box_p, anchors)  # [27429, 4]
    
    num_class = class_p.shape[0] - 1

    # exclude the background class
    class_p = class_p[1:, :]
    # TODO: Apply softmax to the scores
    # get the max score class of 27429 predicted boxes
    class_p_max = tf.reduce_max(class_p, axis=0)  # [27429]
    tf.print(class_p_max.shape)

    # filter predicted boxes according the class score
    keep = tf.where(class_p_max > 0.5)
    class_thre = tf.squeeze(tf.gather(class_p, keep, axis=1)) # scores; [NUM_CLS, NUM_B]
    if num_class == 1:
        class_thre = tf.expand_dims(class_thre, axis=0) # [NUM_CLS, NUM_B]
    box_thre = tf.squeeze(tf.gather(box_decode, keep, axis=0)) # boxes; [NUM_B, 4]
    coef_thre = tf.squeeze(tf.gather(coef_p, keep, axis=0)) # masks; [NUM_B, 32]

    if class_thre.shape[1] == 0:
        result = None
    else:
        if not trad_nms:
            box_thre, coef_thre, class_ids, class_thre = _fast_nms(box_thre, coef_thre, class_thre)
        else:
            tic = time.time()
            box_thre, coef_thre, class_ids, class_thre = _traditional_nms(box_thre, coef_thre, class_thre)
            print("fps: ", 1/(time.time()-tic))

        result = {'detection_boxes_raw':box_thre, 'detection_masks_coef': coef_thre, 'detection_classes': class_ids, 'detection_scores': class_thre}

        if result is not None and proto_p is not None:
            # At this points masks is only the coefficients
            result['detection_masks_proto'] = proto_p
            
            masks = tf.sigmoid(tf.matmul(proto_p, tf.transpose(coef_thre))) # (90, 302, 32) x (32, 300)  = (90, 302, 300)

            boxes, masks = _crop_and_normalize(masks, box_thre)
            result['detection_boxes'] = boxes
            result['detection_masks'] = masks
    return result

# %%
out_dic = post_process(net_outs)
# Out:
# TensorShape([27429])
# fps:  465.25834719911256

# %%
for box in out_dic['detection_boxes_raw'].numpy():
    box = np.round(box).astype(int)
    image = cv2.rectangle(img_test, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)
plt.imshow(image)

# %%
out_dic['detection_boxes_raw']
# Out:
# <tf.Tensor: shape=(14, 4), dtype=float32, numpy=
# array([[ 569.6381   ,  -12.309673 , 2000.9056   ,   71.08107  ],
#        [ 235.7011   ,  -48.71236  ,  736.3817   ,  172.0954   ],
#        [ 306.70886  ,   70.40976  , 1186.6757   ,  534.747    ],
#        [ 390.00134  ,  -61.42088  ,  852.4485   ,  100.75752  ],
#        [ 301.15527  ,  -10.810772 , 1360.2876   ,  172.28587  ],
#        [ 194.19849  ,  -35.794983 ,  648.91833  ,   16.748985 ],
#        [  96.73428  ,   33.180542 ,  648.05853  ,  279.18225  ],
#        [ 628.1976   ,  -51.087475 , 1705.3036   ,   97.04381  ],
#        [  61.475418 ,   -8.486359 ,  350.88037  ,  328.71497  ],
#        [ 342.61664  ,  -21.916079 ,  984.14905  ,   76.71408  ],
#        [ 125.11333  ,   -3.1977768,  837.52014  ,  131.6663   ],
#        [ 391.38443  ,  111.89377  , 1694.5187   ,  451.7339   ],
#        [ 253.59749  ,   34.780533 ,  817.5105   ,  242.6664   ],
#        [  47.46324  ,  -27.161243 ,  536.03723  ,   48.201397 ]],
#       dtype=float32)>

# %%
out_dic['detection_boxes']
# Out:
# <tf.Tensor: shape=(14, 4), dtype=float32, numpy=
# array([[1.        , 0.        , 1.        , 0.23867904],
#        [1.        , 0.        , 1.        , 0.57316357],
#        [1.        , 0.22983365, 1.        , 1.        ],
#        [1.        , 0.        , 1.        , 0.33694544],
#        [1.        , 0.        , 1.        , 0.5737943 ],
#        [1.        , 0.        , 1.        , 0.05877148],
#        [1.        , 0.10655808, 1.        , 0.9277558 ],
#        [1.        , 0.        , 1.        , 0.32464838],
#        [0.6719491 , 0.        , 1.        , 1.        ],
#        [1.        , 0.        , 1.        , 0.2573314 ],
#        [1.        , 0.        , 1.        , 0.4392924 ],
#        [1.        , 0.3671979 , 1.        , 1.        ],
#        [1.        , 0.11185607, 1.        , 0.8068424 ],
#        [0.51625824, 0.        , 1.        , 0.16291854]], dtype=float32)>

# %%
for _ in range(20):
    tic = time.time()
    forward(img[None, ...])
    print("fps: ", 1/(time.time() - tic))
# Out:
# fps:  92.34690327836368
# fps:  23.88501400879251
# fps:  23.691011172490143
# fps:  24.003662668253824
# fps:  20.48060001757864
# fps:  28.248656366599764
# fps:  25.610942175001526
# fps:  25.976873958739773
# fps:  25.847845244624665
# fps:  25.700392156862744
# fps:  26.001996193593584
# fps:  25.605157288760555
# fps:  25.70858361732905
# fps:  26.169258029898426
# fps:  26.12410854982467
# fps:  25.93527163898542
# fps:  26.064690931462412
# fps:  25.773353488429255
# fps:  26.187557753302865
# fps:  25.982828045048507

# %% [markdown]
# # Saved_model to frozen_graph

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

loaded = tf.saved_model.load('./saved_model')
infer = loaded.signatures['serving_default']
f = tf.function(infer).get_concrete_function(inputs=tf.TensorSpec(shape=[None, None, None, 3], dtype=tf.uint8))
f2 = convert_variables_to_constants_v2(f)
graph_def = f2.graph.as_graph_def()

for node in graph_def.node:
    print(node.op, node.name)

with tf.io.gfile.GFile('frozen_graph.pb', 'wb') as f:
    f.write(graph_def.SerializeToString())
# Out:
# Placeholder inputs
# Const 528902
# Const 528920
# Const 528938
# Const 528956
# Const 528970
# Const 528986
# Const 528998
# Const 528840
# Const 528854
# Const 528870
# Const 528888
# Const 528904
# Const 528922
# Const 528940
# Const 528958
# Const 528972
# Const 528988
# Const 529000
# Const 529014
# Const 529028
# Const 528856
# Const 528872
# Const 528890
# Const 528906
# Const 528924
# Const 528942
# Const 528748
# Const 528974
# Const 528990
# Const 529002
# Const 529016
# Const 529030
# Const 528842
# Const 528858
# Const 528874
# Const 528892
# Const 528908
# Const 528926
# Const 528944
# Const 528730
# Const 528750
# Const 528762
# Const 529004
# Const 529018
# Const 529032
# Const 528826
# Const 528844
# Const 528860
# Const 528876
# Const 528894
# Const 528910
# Const 528928
# Const 528694
# Const 528708
# Const 528734
# Const 528752
# Const 529006
# Const 529020
# Const 529034
# Const 528808
# Const 528828
# Const 528846
# Const 528862
# Const 528878
# Const 528896
# Const 528912
# Const 528668
# Const 528682
# Const 528696
# Const 528710
# Const 528738
# Const 528754
# Const 529022
# Const 529036
# Const 528792
# Const 528818
# Const 528830
# Const 528848
# Const 528864
# Const 528880
# Const 528636
# Const 528650
# Const 528670
# Const 528684
# Const 528698
# Const 528712
# Const 528724
# Const 528740
# Const 529038
# Const 528778
# Const 528802
# Const 528810
# Const 528832
# Const 528638
# Const 528660
# Const 528674
# Const 528686
# Const 528714
# Const 528726
# Const 528742
# Const 528764
# Const 528780
# Const 528794
# Const 528816
# Const 528644
# Const 528652
# Const 528676
# Const 528688
# Const 528728
# Const 528744
# Const 528766
# Const 528786
# Const 528800
# Const 528812
# Const 529100
# Const 529078
# Const 529084
# Const 529102
# Const 529116
# Const 529080
# Const 529086
# Const 529104
# Const 528640
# Const 528654
# Const 528672
# Const 528690
# Const 529106
# Const 529118
# Const 528736
# Const 529056
# Const 528768
# Const 528782
# Const 528796
# Const 528814
# Const 529132
# Const 529148
# Const 529164
# Const 529082
# Const 529088
# Const 529108
# Const 529120
# Const 529134
# Const 529150
# Const 529166
# Const 528658
# Const 529196
# Const 529090
# Const 529110
# Const 529044
# Const 529058
# Const 529072
# Const 528756
# Const 528784
# Const 528798
# Const 529210
# Const 529092
# Const 529112
# Const 529122
# Const 529136
# Const 529152
# Const 529168
# Const 529180
# Const 529198
# Const 529212
# Const 529226
# Const 529094
# Const 529114
# Const 529124
# Const 529138
# Const 529046
# Const 529060
# Const 529074
# Const 529200
# Const 528758
# Const 528772
# Const 528788
# Const 529096
# Const 529274
# Const 529126
# Const 529140
# Const 529154
# Const 529170
# Const 529182
# Const 529202
# Const 529214
# Const 529228
# Const 529242
# Const 529258
# Const 529098
# Const 529290
# Const 529128
# Const 529048
# Const 529062
# Const 529076
# Const 529184
# Const 529204
# Const 528760
# Const 528774
# Const 529244
# Const 529260
# Const 529276
# Const 529292
# Const 529306
# Const 529130
# Const 529142
# Const 529156
# Const 529172
# Const 529186
# Const 529206
# Const 529216
# Const 529230
# Const 529246
# Const 529262
# Const 529278
# Const 529050
# Const 529064
# Const 529322
# Const 529336
# Const 529144
# Const 529158
# Const 529174
# Const 529188
# Const 529208
# Const 529218
# Const 529232
# Const 529248
# Const 529264
# Const 529280
# Const 529294
# Const 529308
# Const 529324
# Const 529338
# Const 529146
# Const 529160
# Const 529176
# Const 529190
# Const 529052
# Const 529066
# Const 529250
# Const 529266
# Const 529282
# Const 529296
# Const 529310
# Const 529326
# Const 529340
# Const 529162
# Const 529178
# Const 529192
# Const 529220
# Const 529234
# Const 529252
# Const 529268
# Const 529284
# Const 529298
# Const 529312
# Const 529328
# Const 529342
# Const 529054
# Const 529068
# Const 529194
# Const 529222
# Const 529236
# Const 529254
# Const 529270
# Const 529286
# Const 529300
# Const 529314
# Const 529330
# Const 529224
# Const 529070
# Const 529256
# Const 529272
# Const 529288
# Const 529302
# Const 529316
# Const 529332
# Const 529238
# Const 529304
# Const 529318
# Const 529334
# Const 529240
# Const 529320
# Const 528642
# Const 528646
# Const 528662
# Const 528692
# Const 528700
# Const 528722
# Const 528732
# Const 528746
# Const 528770
# Const 528776
# Const 528790
# Const 528804
# Const 528820
# Const 528822
# Const 528806
# Const 528716
# Const 528834
# Const 528664
# Const 528914
# Const 528930
# Const 528946
# Const 528960
# Const 528976
# Const 528948
# Const 528678
# Const 528702
# Const 528992
# Const 528962
# Const 528978
# Const 528648
# Const 529008
# Const 528680
# Const 528704
# Const 528824
# Const 528932
# Const 528850
# Const 528964
# Const 528656
# Const 528666
# Const 529010
# Const 529024
# Const 528836
# Const 528852
# Const 528980
# Const 528994
# Const 528898
# Const 528916
# Const 529040
# Const 528950
# Const 528838
# Const 528718
# Const 528866
# Const 528882
# Const 529026
# Const 529042
# Const 528934
# Const 528952
# Const 528966
# Const 528982
# Const 528706
# Const 528720
# Const 528884
# Const 528900
# Const 528918
# Const 528936
# Const 528954
# Const 528968
# Const 528984
# Const 528996
# Const 529012
# Const 528868
# Const 528886
# NoOp Func/StatefulPartitionedCall/input_control_node/_0
# Identity Func/StatefulPartitionedCall/input/_1
# NoOp Func/StatefulPartitionedCall/StatefulPartitionedCall/input_control_node/_362
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_363
# Cast StatefulPartitionedCall/StatefulPartitionedCall/model_25/Cast
# Const StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_pad/Pad/paddings
# Pad StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_pad/Pad
# Identity Func/StatefulPartitionedCall/input/_2
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_364
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_3
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_365
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_4
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_366
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_5
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_367
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_6
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_368
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_7
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_369
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv1_relu/Relu
# Const StatefulPartitionedCall/StatefulPartitionedCall/model_25/pool1_pad/Pad/paddings
# Pad StatefulPartitionedCall/StatefulPartitionedCall/model_25/pool1_pad/Pad
# MaxPool StatefulPartitionedCall/StatefulPartitionedCall/model_25/pool1_pool/MaxPool
# Identity Func/StatefulPartitionedCall/input/_22
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_384
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_23
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_385
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_24
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_386
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_25
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_387
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_26
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_388
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_27
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_389
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_0_bn/FusedBatchNormV3
# Identity Func/StatefulPartitionedCall/input/_8
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_370
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_9
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_371
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_10
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_372
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_11
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_373
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_12
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_374
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_13
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_375
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_1_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_14
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_376
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_15
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_377
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_16
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_378
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_17
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_379
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_18
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_380
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_19
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_381
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_2_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_20
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_382
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_21
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_383
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_28
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_390
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_29
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_391
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_30
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_392
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_31
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_393
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_3_bn/FusedBatchNormV3
# AddV2 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_add/add
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block1_out/Relu
# Identity Func/StatefulPartitionedCall/input/_32
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_394
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_33
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_395
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_34
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_396
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_35
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_397
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_36
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_398
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_37
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_399
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_1_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_38
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_400
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_39
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_401
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_40
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_402
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_41
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_403
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_42
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_404
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_43
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_405
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_2_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_44
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_406
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_45
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_407
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_46
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_408
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_47
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_409
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_48
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_410
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_49
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_411
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_3_bn/FusedBatchNormV3
# AddV2 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_add/add
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block2_out/Relu
# Identity Func/StatefulPartitionedCall/input/_50
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_412
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_51
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_413
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_52
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_414
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_53
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_415
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_54
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_416
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_55
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_417
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_1_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_56
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_418
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_57
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_419
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_58
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_420
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_59
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_421
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_60
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_422
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_61
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_423
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_2_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_62
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_424
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_63
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_425
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_64
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_426
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_65
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_427
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_66
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_428
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_67
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_429
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_3_bn/FusedBatchNormV3
# AddV2 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_add/add
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv2_block3_out/Relu
# Identity Func/StatefulPartitionedCall/input/_82
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_444
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_83
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_445
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_84
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_446
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_85
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_447
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_86
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_448
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_87
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_449
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_0_bn/FusedBatchNormV3
# Identity Func/StatefulPartitionedCall/input/_68
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_430
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_69
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_431
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_70
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_432
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_71
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_433
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_72
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_434
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_73
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_435
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_1_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_74
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_436
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_75
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_437
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_76
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_438
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_77
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_439
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_78
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_440
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_79
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_441
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_2_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_80
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_442
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_81
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_443
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_88
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_450
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_89
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_451
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_90
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_452
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_91
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_453
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_3_bn/FusedBatchNormV3
# AddV2 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_add/add
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block1_out/Relu
# Identity Func/StatefulPartitionedCall/input/_92
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_454
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_93
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_455
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_94
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_456
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_95
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_457
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_96
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_458
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_97
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_459
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_1_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_98
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_460
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_99
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_461
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_100
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_462
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_101
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_463
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_102
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_464
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_103
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_465
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_2_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_104
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_466
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_105
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_467
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_106
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_468
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_107
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_469
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_108
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_470
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_109
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_471
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_3_bn/FusedBatchNormV3
# AddV2 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_add/add
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block2_out/Relu
# Identity Func/StatefulPartitionedCall/input/_110
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_472
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_111
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_473
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_112
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_474
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_113
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_475
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_114
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_476
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_115
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_477
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_1_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_116
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_478
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_117
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_479
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_118
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_480
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_119
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_481
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_120
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_482
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_121
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_483
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_2_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_122
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_484
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_123
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_485
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_124
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_486
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_125
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_487
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_126
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_488
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_127
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_489
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_3_bn/FusedBatchNormV3
# AddV2 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_add/add
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block3_out/Relu
# Identity Func/StatefulPartitionedCall/input/_128
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_490
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_129
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_491
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_130
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_492
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_131
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_493
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_132
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_494
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_133
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_495
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_1_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_134
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_496
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_135
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_497
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_136
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_498
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_137
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_499
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_138
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_500
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_139
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_501
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_bn/FusedBatchNormV3
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_2_relu/Relu
# Identity Func/StatefulPartitionedCall/input/_140
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_502
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_conv/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_conv/Conv2D
# Identity Func/StatefulPartitionedCall/input/_141
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_503
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_conv/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_conv/BiasAdd
# Identity Func/StatefulPartitionedCall/input/_142
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_504
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_bn/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_143
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_505
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_bn/ReadVariableOp_1
# Identity Func/StatefulPartitionedCall/input/_144
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_506
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_bn/FusedBatchNormV3/ReadVariableOp
# Identity Func/StatefulPartitionedCall/input/_145
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_507
# Identity StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_bn/FusedBatchNormV3/ReadVariableOp_1
# FusedBatchNormV3 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_3_bn/FusedBatchNormV3
# AddV2 StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_add/add
# Relu StatefulPartitionedCall/StatefulPartitionedCall/model_25/conv3_block4_out/Relu
# Identity Func/StatefulPartitionedCall/input/_160
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_522
# ...
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_2/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_2/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_2/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_2
# Tanh StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Tanh
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_391/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_391/Conv2D
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_391/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_391/BiasAdd
# Shape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Shape_2
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_2/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_2/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_2/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_2
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_2/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_2/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_2/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_2
# Tanh StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Tanh
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_391/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_391/Conv2D
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_391/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_391/BiasAdd
# Shape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Shape_2
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_2/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_2/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_2/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_2
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_2/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_2/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_2/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_2
# Tanh StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Tanh
# Const StatefulPartitionedCall/StatefulPartitionedCall/concat_2/axis
# ConcatV2 StatefulPartitionedCall/StatefulPartitionedCall/concat_2
# Identity StatefulPartitionedCall/StatefulPartitionedCall/Identity_1
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/output/_719
# Identity StatefulPartitionedCall/Identity_1
# Identity Func/StatefulPartitionedCall/output/_357
# Identity Identity_1
# Identity Func/StatefulPartitionedCall/input/_352
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_714
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/conv2d_390/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/conv2d_390/Conv2D
# Identity Func/StatefulPartitionedCall/input/_353
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_715
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/conv2d_390/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/conv2d_390/BiasAdd
# Shape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/Shape_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/strided_slice_1/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/strided_slice_1/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/strided_slice_1/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/strided_slice_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/Reshape_1/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/Reshape_1/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/Reshape_1/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20/Reshape_1
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/conv2d_390/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/conv2d_390/Conv2D
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/conv2d_390/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/conv2d_390/BiasAdd
# Shape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/Shape_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/strided_slice_1/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/strided_slice_1/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/strided_slice_1/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/strided_slice_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/Reshape_1/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/Reshape_1/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/Reshape_1/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_1/Reshape_1
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/conv2d_390/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/conv2d_390/Conv2D
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/conv2d_390/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/conv2d_390/BiasAdd
# Shape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Shape_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/strided_slice_1/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/strided_slice_1/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/strided_slice_1/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/strided_slice_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_1/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_1/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_1/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_2/Reshape_1
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_390/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_390/Conv2D
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_390/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/conv2d_390/BiasAdd
# Shape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Shape_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_1/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_1/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_1/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/strided_slice_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_1/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_1/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_1/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_3/Reshape_1
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_390/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_390/Conv2D
# Identity StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_390/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/conv2d_390/BiasAdd
# Shape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Shape_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_1/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_1/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_1/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/strided_slice_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_1/shape/1
# Const StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_1/shape/2
# Pack StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_1/shape
# Reshape StatefulPartitionedCall/StatefulPartitionedCall/prediction_module_20_4/Reshape_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/concat_1/axis
# ConcatV2 StatefulPartitionedCall/StatefulPartitionedCall/concat_1
# Identity StatefulPartitionedCall/StatefulPartitionedCall/Identity_2
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/output/_720
# Identity StatefulPartitionedCall/Identity_2
# Identity Func/StatefulPartitionedCall/output/_358
# Identity Identity_2
# Identity Func/StatefulPartitionedCall/input/_336
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_698
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_382/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_382/Conv2D
# Identity Func/StatefulPartitionedCall/input/_337
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_699
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_382/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_382/BiasAdd
# Relu StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_382/Relu
# Identity Func/StatefulPartitionedCall/input/_338
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_700
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_383/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_383/Conv2D
# Identity Func/StatefulPartitionedCall/input/_339
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_701
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_383/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_383/BiasAdd
# Relu StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_383/Relu
# Identity Func/StatefulPartitionedCall/input/_340
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_702
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_384/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_384/Conv2D
# Identity Func/StatefulPartitionedCall/input/_341
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_703
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_384/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_384/BiasAdd
# Relu StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_384/Relu
# Shape StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/Shape
# Const StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/strided_slice/stack
# Const StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/strided_slice/stack_1
# Const StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/strided_slice/stack_2
# StridedSlice StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/strided_slice
# Const StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/Const
# Mul StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/mul
# ResizeBilinear StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/up_sampling2d_43/resize/ResizeBilinear
# Identity Func/StatefulPartitionedCall/input/_342
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_704
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_385/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_385/Conv2D
# Identity Func/StatefulPartitionedCall/input/_343
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_705
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_385/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_385/BiasAdd
# Relu StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_385/Relu
# Identity Func/StatefulPartitionedCall/input/_344
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_706
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_386/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_386/Conv2D
# Identity Func/StatefulPartitionedCall/input/_345
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_707
# Identity StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_386/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_386/BiasAdd
# Relu StatefulPartitionedCall/StatefulPartitionedCall/proto_net_21/conv2d_386/Relu
# Identity StatefulPartitionedCall/StatefulPartitionedCall/Identity_3
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/output/_721
# Identity StatefulPartitionedCall/Identity_3
# Identity Func/StatefulPartitionedCall/output/_359
# Identity Identity_3
# Identity Func/StatefulPartitionedCall/input/_346
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_708
# Identity StatefulPartitionedCall/StatefulPartitionedCall/conv2d_387/Conv2D/ReadVariableOp
# Conv2D StatefulPartitionedCall/StatefulPartitionedCall/conv2d_387/Conv2D
# Identity Func/StatefulPartitionedCall/input/_347
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/input/_709
# Identity StatefulPartitionedCall/StatefulPartitionedCall/conv2d_387/BiasAdd/ReadVariableOp
# BiasAdd StatefulPartitionedCall/StatefulPartitionedCall/conv2d_387/BiasAdd
# Identity StatefulPartitionedCall/StatefulPartitionedCall/Identity_4
# Identity Func/StatefulPartitionedCall/StatefulPartitionedCall/output/_722
# Identity StatefulPartitionedCall/Identity_4
# Identity Func/StatefulPartitionedCall/output/_360
# Identity Identity_4

# %% [markdown]
# # Testing anchor generation code

# %%
import numpy as np
import tensorflow as tf

from YOLACT.data import anchor

test_bbox = tf.convert_to_tensor((np.array([[204.044, 253.8351, 487.8226, 427.06363],
                                            [0, 140.01741, 550, 290.21936],
                                            [40.005028, 117.37102, 255.7913, 205.13097],
                                            [263.31314, 67.0434, 514.04736, 124.48139],
                                            [0, 503.79834, 487.0279, 550]])), dtype=tf.float32)

test_labels = tf.convert_to_tensor((np.array([[1],
                                              [2],
                                              [3],
                                              [4],
                                              [5]])), dtype=tf.float32)

anchorobj = anchor.Anchor(img_size_h=550, img_size_w=550,
                          feature_map_size=[[69,69], [35,35], [18,18], [9,9], [5,5]],
                          aspect_ratio=[1, 0.5, 2],
                          scale=[24, 48, 96, 192, 384])

# %%
def make_anchors(img_size, conv_h, conv_w, scale, aspect_ratios):
    prior_data = []
    # Iteration order is important (it has to sync up with the convout)
    for j, i in product(range(conv_h), range(conv_w)):
        # + 0.5 because priors are in center
        x = (i + 0.5) / conv_w
        y = (j + 0.5) / conv_h

        for ar in aspect_ratios:
            ar = sqrt(ar)
            w = scale * ar / img_size
            h = scale / ar / img_size
            
            prior_data += [x, y, w, h]

    return prior_data

# %%
feature_map_size=[[69,69], [35,35], [18,18], [9,9], [5,5]]
aspect_ratios=[1, 0.5, 2]
scales=[24, 48, 96, 192, 384]
anchors = []

for i, shape in enumerate(feature_map_size):
    anchors += make_anchors(550, shape[0], shape[1], scales[i], aspect_ratios)
    
anchors = tf.reshape(tf.convert_to_tensor(anchors), [-1, 4])

# %%
def encode(map_loc, center_anchors, include_variances=False):
    # center_gt = tf.map_fn(lambda x: map_to_center_form(x), map_loc)
    h = map_loc[:, 2] - map_loc[:, 0]
    w = map_loc[:, 3] - map_loc[:, 1]
    center_gt = tf.cast(tf.stack([map_loc[:, 1] + (w / 2), map_loc[:, 0] + (h / 2), w, h], axis=-1), tf.float32)
    variances = [0.1, 0.2]

    # calculate offset
    if include_variances:
        g_hat_cx = (center_gt[:, 0] - center_anchors[:, 0]) / center_anchors[:, 2] / variances[0]
        g_hat_cy = (center_gt[:, 1] - center_anchors[:, 1]) / center_anchors[:, 3] / variances[0]
    else:
        g_hat_cx = (center_gt[:, 0] - center_anchors[:, 0]) / center_anchors[:, 2]
        g_hat_cy = (center_gt[:, 1] - center_anchors[:, 1]) / center_anchors[:, 3]
    tf.debugging.assert_non_negative(center_anchors[:, 2] / center_gt[:, 2])
    tf.debugging.assert_non_negative(center_anchors[:, 3] / center_gt[:, 3])
    if include_variances:
        g_hat_w = tf.math.log(center_gt[:, 2] / center_anchors[:, 2]) / variances[1]
        g_hat_h = tf.math.log(center_gt[:, 3] / center_anchors[:, 3]) / variances[1]
    else:
        g_hat_w = tf.math.log(center_gt[:, 2] / center_anchors[:, 2])
        g_hat_h = tf.math.log(center_gt[:, 3] / center_anchors[:, 3])
    offsets = tf.stack([g_hat_cx, g_hat_cy, g_hat_w, g_hat_h], axis=-1)
    return offsets

# %%
def area(boxlist, scope=None):
    # https://github.com/tensorflow/models/blob/831281cedfc8a4a0ad7c0c37173963fafb99da37/official/vision/detection/utils/object_detection/box_list_ops.py#L48
    """Computes area of boxes.
    Args:
    boxlist: BoxList holding N boxes
    scope: name scope.
    Returns:
    a tensor with shape [N] representing box areas.
    """
    y_min, x_min, y_max, x_max = tf.split(
        value=boxlist, num_or_size_splits=4, axis=1)
    return tf.squeeze((y_max - y_min) * (x_max - x_min), [1])

# %%
def intersection(boxlist1, boxlist2, scope=None):
    # https://github.com/tensorflow/models/blob/831281cedfc8a4a0ad7c0c37173963fafb99da37/official/vision/detection/utils/object_detection/box_list_ops.py#L209
    """Compute pairwise intersection areas between boxes.
    Args:
    boxlist1: BoxList holding N boxes
    boxlist2: BoxList holding M boxes
    scope: name scope.
    Returns:
    a tensor with shape [N, M] representing pairwise intersections
    """
    y_min1, x_min1, y_max1, x_max1 = tf.split(
        value=boxlist1, num_or_size_splits=4, axis=1)
    y_min2, x_min2, y_max2, x_max2 = tf.split(
        value=boxlist2, num_or_size_splits=4, axis=1)
    all_pairs_min_ymax = tf.minimum(y_max1, tf.transpose(y_max2))
    all_pairs_max_ymin = tf.maximum(y_min1, tf.transpose(y_min2))
    intersect_heights = tf.maximum(0.0, all_pairs_min_ymax - all_pairs_max_ymin)
    all_pairs_min_xmax = tf.minimum(x_max1, tf.transpose(x_max2))
    all_pairs_max_xmin = tf.maximum(x_min1, tf.transpose(x_min2))
    intersect_widths = tf.maximum(0.0, all_pairs_min_xmax - all_pairs_max_xmin)
    return intersect_heights * intersect_widths

# %%
def iou(boxlist1, boxlist2, scope=None):
    # https://github.com/tensorflow/models/blob/831281cedfc8a4a0ad7c0c37173963fafb99da37/official/vision/detection/utils/object_detection/box_list_ops.py#L259
    """Computes pairwise intersection-over-union between box collections.
    Args:
    boxlist1: BoxList holding N boxes
    boxlist2: BoxList holding M boxes
    scope: name scope.
    Returns:
    a tensor with shape [N, M] representing pairwise iou scores.
    """
    intersections = intersection(boxlist1, boxlist2)
    areas1 = area(boxlist1)
    areas2 = area(boxlist2)
    unions = (
        tf.expand_dims(areas1, 1) + tf.expand_dims(areas2, 0) - intersections)
    return tf.where(
        tf.equal(intersections, 0.0),
        tf.zeros_like(intersections), tf.truediv(intersections, unions))

# %%
def matching(pos_thresh, neg_thresh, gt_bbox, gt_labels, priors):
    pairwise_iou = iou(priors, gt_bbox) # # size: [num_objects, num_priors]; anchors along the row and ground_truth clong the columns

    each_prior_max = tf.reduce_max(pairwise_iou, axis=-1) # size [num_priors]; iou with ground truth with the anchors
    each_prior_index = tf.math.argmax(pairwise_iou, axis=-1) # size [num_priors]; id of groud truth having max iou with the anchors

    each_box_max = tf.reduce_max(pairwise_iou, axis=0)
    each_box_index = tf.math.argmax(pairwise_iou, axis=0)

    # For the max IoU prior for each gt box, set its IoU to 2. This ensures that it won't be filtered
    # in the threshold step even if the IoU is under the negative threshold. This is because that we want
    # at least one prior to match with each gt box or else we'd be wasting training data.

    indices = tf.expand_dims(each_box_index,axis=-1)

    updates = tf.cast(tf.tile(tf.constant([2]), each_box_index.shape), dtype=tf.float32)
    each_prior_max = tf.tensor_scatter_nd_update(each_prior_max, indices, updates)

    # Set the index of the pair (prior, gt) we set the overlap for above.
    updates = tf.cast(tf.range(0,each_box_index.shape),dtype=tf.int64)
    each_prior_index = tf.tensor_scatter_nd_update(each_prior_index, indices, updates)

    each_prior_box = tf.gather(gt_bbox, each_prior_index) # size: [num_priors, 4]
    conf = tf.squeeze(tf.gather(gt_labels, each_prior_index) + 1) # the class of the max IoU gt box for each prior, size: [num_priors]


    neutral_label_index = tf.where(each_prior_max < pos_thresh)
    background_label_index = tf.where(each_prior_max < neg_thresh)

    conf = tf.tensor_scatter_nd_update(conf, neutral_label_index, -1*tf.ones(tf.size(neutral_label_index)))
    conf = tf.tensor_scatter_nd_update(conf, background_label_index, tf.zeros(tf.size(background_label_index)))

    offsets = encode(each_prior_box, priors)

    return offsets, conf, each_prior_box, each_prior_index

# %%
offsets, conf, each_prior_box, each_prior_index = \
    matching(0.5, 0.5, test_bbox/550, test_labels, anchors)

# %%
each_prior_box
# Out:
# <tf.Tensor: shape=(19248, 4), dtype=float32, numpy=
# array([[0.3709891 , 0.46151835, 0.8869502 , 0.7764793 ],
#        [0.3709891 , 0.46151835, 0.8869502 , 0.7764793 ],
#        [0.3709891 , 0.46151835, 0.8869502 , 0.7764793 ],
#        ...,
#        [0.3709891 , 0.46151835, 0.8869502 , 0.7764793 ],
#        [0.3709891 , 0.46151835, 0.8869502 , 0.7764793 ],
#        [0.3709891 , 0.46151835, 0.8869502 , 0.7764793 ]], dtype=float32)>

# %%
_idx = tf.where(conf > 0.5)

# %%
_test = _decode(offsets, anchorobj.anchors)

# %%
_out = tf.squeeze(tf.gather(_test, _idx)).numpy()*550

# %%
_out
# Out:
# array([[ 40.00502, 117.37102, 255.79132, 205.13097],
#        [  0.     , 140.01741, 550.     , 290.21936],
#        [263.31314,  67.0434 , 514.04736, 124.48139],
#        [  0.     , 140.01741, 550.     , 290.21936],
#        [204.04402, 253.8351 , 487.8226 , 427.06363],
#        [  0.     , 503.79837, 487.0279 , 550.     ]], dtype=float32)

# %%
test_bbox
# Out:
# <tf.Tensor: shape=(5, 4), dtype=float32, numpy=
# array([[204.044   , 253.8351  , 487.8226  , 427.06363 ],
#        [  0.      , 140.01741 , 550.      , 290.21936 ],
#        [ 40.005028, 117.37102 , 255.7913  , 205.13097 ],
#        [263.31314 ,  67.0434  , 514.04736 , 124.48139 ],
#        [  0.      , 503.79834 , 487.0279  , 550.      ]], dtype=float32)>

# %%
img_test = 255*np.ones((1000,1000,3), dtype=np.int8)

for box in _out:
    box = np.round(box).astype(int)
    image = cv2.rectangle(img_test, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)
plt.imshow(image)

# %%
img_test = 255*np.ones((1000,1000,3), dtype=np.int8)

for box in test_bbox.numpy():
    box = np.round(box).astype(int)
    image = cv2.rectangle(img_test, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)
plt.imshow(image)

# %% [markdown]
# # Testing loss function

# %%
label=np.load('../label.npy',allow_pickle=True).tolist()
pred=np.load('../pred.npy',allow_pickle=True).tolist()

# %%
gt_offset = label['all_offsets'].numpy()[0]
pred_offset = pred['pred_offset'].numpy()[0]

# %%
pred_cls = pred['pred_cls'].numpy()[0]
num_classes = 2
conf_gt = label['conf_gt'].numpy()[0]

# %%
_test = _decode(gt_offset, model.priors)

# %%
conf_gt = label['conf_gt'].numpy()[0]

# %%
pos_indices = tf.where(conf_gt > 0)

# %%
_out = tf.squeeze(tf.gather(_test, pos_indices)).numpy()*[360, 1205, 360, 1205]

# %%
img_test = 255*np.ones((360,1205,3), dtype=np.int8)

for box in _out:
    box = np.round(box).astype(int)
    image = cv2.rectangle(img_test, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)
plt.imshow(image)

# %%
pred_offset = tf.gather_nd(pred_offset, pos_indices)
gt_offset = tf.gather_nd(gt_offset, pos_indices)

# %%
pred_offset
# Out:
# <tf.Tensor: shape=(3, 4), dtype=float32, numpy=
# array([[-1.1775408 ,  0.01081492,  4.00686   , -0.7663659 ],
#        [ 0.00773525,  0.23271799,  1.3533934 , -0.7368684 ],
#        [ 0.43033195, -0.12754941, -0.6475735 , -0.82432246]],
#       dtype=float32)>

# %%
gt_offset
# Out:
# <tf.Tensor: shape=(3, 4), dtype=float32, numpy=
# array([[ 3.5312916e+01,  9.9687490e+00,  1.2163953e+00,  1.4120027e+00],
#        [ 2.0716145e+00,  6.5104193e-03, -8.3865488e-01, -1.0161686e+00],
#        [ 8.8480431e-01, -8.2864076e-02, -6.1363631e-01, -4.9812350e-01]],
#       dtype=float32)>

# %%
def _loss_location(pred_offset, gt_offset):
    # calculate the smoothL1(positive_pred, positive_gt) and return
    num_pos = tf.shape(gt_offset)[0]
    smoothl1loss = tf.keras.losses.Huber(delta=1., reduction=tf.losses.Reduction.NONE)
    loss_loc = tf.reduce_sum(smoothl1loss(gt_offset, pred_offset)) / tf.cast(num_pos, tf.float32)

    return loss_loc

# %%
_loss_location(pred_offset, gt_offset)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=4.407983>

# %%
class_p = pred['pred_cls'].numpy()[0]

# %%
class_p.shape # one-hot encoded
# Out:
# (27429, 2)

# %%
conf_gt.shape
# Out:
# (27429,)

# %%
batch_conf = class_p

batch_conf_max = class_p.max()
mark = np.log(np.sum(np.exp(batch_conf - batch_conf_max), 1)) + batch_conf_max - batch_conf[:, 0]

# %%
# Hard Negative Mining
class_p.shape
# Out:
# (27429, 2)

# %%
mark = mark.reshape((class_p.shape[0], -1))

# %%
conf_gt.shape
# Out:
# (27429,)

# %%
np.sum(np.exp(batch_conf - batch_conf_max), 1)
# Out:
# array([0.02895284, 0.0038396 , 0.00401568, ..., 0.00241419, 0.00309208,
#        0.00281499], dtype=float32)

# %%
batch_conf_max - batch_conf[:, 0]
# Out:
# array([7.4525847, 6.1767883, 6.8137903, ..., 6.5486817, 6.529446 ,
#        6.4704933], dtype=float32)

# %%
batch_conf
# Out:
# array([[-1.1315335 ,  2.7587304 ],
#        [ 0.14426276, -0.01996291],
#        [-0.49273938,  0.4839047 ],
#        ...,
#        [-0.2276308 , -0.6046777 ],
#        [-0.20839486, -0.0967323 ],
#        [-0.1494422 , -0.35042235]], dtype=float32)

# %%
np.count_nonzero(conf_gt)
# Out:
# 3

# %%
def _loss_class(pred_cls, num_cls, conf_gt):
    batch_conf = tf.reshape(pred_cls, [-1, num_cls])
    batch_conf_max = tf.math.reduce_max(pred_cls)

    # Hard Negative Mining

    # This will be used to determine unaveraged confidence loss across all examples in a batch.
    # https://github.com/dbolya/yolact/blob/b97e82d809e5e69dc628930070a44442fd23617a/layers/modules/multibox_loss.py#L251
    # https://github.com/dbolya/yolact/blob/b97e82d809e5e69dc628930070a44442fd23617a/layers/box_utils.py#L316
    mark = tf.math.log(tf.math.reduce_sum(tf.math.exp(batch_conf-batch_conf_max), 1)) + batch_conf_max - batch_conf[:,0]

    mark = tf.reshape(mark, (tf.shape(pred_cls)[0], -1))  # (n, 27429)
    pos_indices = tf.where(conf_gt > 0 )
    mark = tf.tensor_scatter_nd_update(mark, pos_indices, tf.zeros(tf.shape(pos_indices)[0])) # filter out pos boxes
    num_pos = tf.math.count_nonzero(tf.greater(conf_gt,0), axis=1, keepdims=True)
    num_neg = num_pos * self._neg_pos_ratio

    neutrals_indices = tf.where(conf_gt < 0 )
    mark = tf.tensor_scatter_nd_update(mark, neutrals_indices, tf.zeros(tf.shape(neutrals_indices)[0])) # filter out neutrals (conf_gt = -1)

    idx = tf.argsort(mark, axis=1, direction='DESCENDING')
    idx_rank = tf.argsort(idx, axis=1)

    # Just in case there aren't enough negatives, don't start using positives as negatives
    # Filter out neutrals and positive
    neg_indices = tf.where((tf.cast(idx_rank, dtype=tf.int64) < num_neg) & (conf_gt == 0))

    neg_pred_cls_for_loss = tf.gather(pred_cls, neg_indices)
    neg_gt_for_loss = tf.gather(conf_gt, neg_indices)
    pos_pred_cls_for_loss = tf.gather(pred_cls, pos_indices)
    pos_gt_for_loss = tf.gather(conf_gt, pos_indices)

    target_logits = tf.concat([pos_pred_cls_for_loss, neg_pred_cls_for_loss], axis=0)
    target_labels = tf.concat([pos_gt_for_loss, neg_gt_for_loss], axis=0)
    target_labels = tf.one_hot(tf.squeeze(target_labels), depth=num_cls)

    loss_conf = tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits(target_labels, target_logits)) / tf.cast(num_pos, tf.float32)

    return loss_conf

# %% [markdown]
# # Mask loss

# %%
def sanitize_coordinates(_x1, _x2, img_size, padding = 0):
    """
    Sanitizes the input coordinates so that x1 < x2, x1 != x2, x1 >= 0, and x2 <= image_size.
    Also converts from relative to absolute coordinates and casts the results to long tensors.
    Warning: this does things in-place behind the scenes so copy if necessary.
    """
    _x1 = _x1 * img_size
    _x2 = _x2 * img_size

    x1 = tf.math.minimum(_x1, _x2)
    x2 = tf.math.maximum(_x1, _x2)
    x1 = tf.clip_by_value(x1 - padding, clip_value_min=0, clip_value_max=img_size)
    x2 = tf.clip_by_value(x2 + padding, clip_value_min=0, clip_value_max=img_size)

    return x1, x2

# %%
# crop the prediction of mask so as to calculate the linear combination mask loss
def crop(mask_p, boxes, padding = 1):
    """
    "Crop" predicted masks by zeroing out everything not in the predicted bbox.
    Args:
        - mask_p should be a size [h, w, n] tensor of masks
        - boxes should be a size [n, 4] tensor of bbox coords in relative point form
    """
    _h, _w, _n = tf.shape(mask_p)

    x1, x2 = sanitize_coordinates(boxes[:, 1], boxes[:, 3], tf.cast(_w, tf.float32), padding)
    y1, y2 = sanitize_coordinates(boxes[:, 0], boxes[:, 2], tf.cast(_h, tf.float32), padding)

    rows = tf.reshape(tf.range(_h, dtype=x1.dtype), (-1, 1, 1))
    cols = tf.reshape(tf.range(_w, dtype=x1.dtype), (1, -1, 1))

    cols = tf.broadcast_to(cols, (_h, _w, _n))
    rows = tf.broadcast_to(rows, (_h, _w, _n))

    mask_left = tf.cast(cols, tf.float32) >= tf.reshape(x1, (1, 1, -1))
    mask_right = tf.cast(cols, tf.float32) <= tf.reshape(x2, (1, 1, -1))
    mask_bottom = tf.cast(rows, tf.float32) >= tf.reshape(y1, (1, 1, -1))
    mask_top = tf.cast(rows, tf.float32) <= tf.reshape(y2, (1, 1, -1))

    crop_mask = tf.math.logical_and(tf.math.logical_and(mask_left, mask_right), tf.math.logical_and(mask_bottom, mask_top))
    crop_mask = tf.cast(crop_mask, tf.float32)

    return mask_p * crop_mask

# %%
shape_proto = tf.shape(proto_p)
proto_h = shape_proto[1]
proto_w = shape_proto[2]
num_batch = shape_proto[0]
loss_m = 0.0

mask_gt = tf.transpose(mask_gt, (0,2,3,1)) #[batch, proto_height, proto_width, num_object]

for i in tf.range(num_batch):
    pos_indices = tf.where(conf_gt[i] > 0 )
    _pos_prior_index = tf.gather_nd(prior_max_index[i], pos_indices) #shape: [num_positives]
    _pos_prior_box = tf.gather_nd(prior_max_box[i], pos_indices) #shape: [num_positives]
    _pos_coef = tf.gather_nd(coef_p[i], pos_indices) #shape: [num_positives]
    _mask_gt = mask_gt[i]

    if _pos_prior_index.shape[0] == 0: # num_positives are zero
        continue
    
    # If exceeds the number of masks for training, select a random subset
    old_num_pos = _pos_coef.shape[0]
    
    if old_num_pos > self._max_masks_for_train:
        perm = tf.random.shuffle(tf.range(_pos_coef.shape[0]))
        select = perm[:self._max_masks_for_train]
        _pos_coef = tf.gather(_pos_coef, select)
        _pos_prior_index = tf.gather(_pos_prior_index, select)
        _pos_prior_box = tf.gather(_pos_prior_box, select)
        
    num_pos = _pos_coef.shape[0]
    _pos_mask_gt = tf.gather(_mask_gt, _pos_prior_index, axis=-1)  
    
    # mask assembly by linear combination
    mask_p = tf.linalg.matmul(proto_p[i], _pos_coef, transpose_a=False, transpose_b=True) # [proto_height, proto_width, num_pos]
    mask_p = tf.math.sigmoid(mask_p)
    
    mask_p = utils.crop(mask_p, _pos_prior_box)  # _pos_prior_box.shape: (num_pos, 4)
    
    mask_loss = tf.keras.losses.binary_crossentropy(_pos_mask_gt, mask_p)
    # Normalize the mask loss to emulate roi pooling's effect on loss.
    pos_get_csize = utils.map_to_center_form(_pos_prior_box)
    mask_loss = tf.reduce_sum(mask_loss, [0, 1]) / pos_get_csize[:, 2] / pos_get_csize[:, 3]
    
    if old_num_pos > num_pos:
        mask_loss *= old_num_pos / num_pos

    loss_m += tf.reduce_sum(mask_loss)
    
loss_m /= tf.cast(proto_h, tf.float32) / tf.cast(proto_w, tf.float32)

# %%
x1 = np.array([161.74445 ,  21.230555,   5.291667])
x2 = np.array([246.375  ,  81.53334,  76.5    ])
y1 = np.array([59.572617, 30.107885, 15.954357])
y2 = np.array([67.622406, 38.307053, 28.93361 ])

# %%
img_test = 255*np.ones((90,302,3), dtype=np.int8)

for box in zip(y1,x1,y2,x2):
    box = np.round(box).astype(int)
    image = cv2.rectangle(img_test, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)
plt.imshow(image)

# %%
mask_p=np.load('../mask_p.npy',allow_pickle=True)
mask_p_crop=np.load('../mask_p_crop.npy',allow_pickle=True)
pos_prior_box=np.load('../pos_prior_box.npy',allow_pickle=True)
pos_mask_gt=np.load('../pos_mask_gt.npy',allow_pickle=True)

mask_p = np.transpose(mask_p, (2, 0, 1))
mask_p_crop = np.transpose(mask_p_crop, (2, 0, 1))
pos_mask_gt = np.transpose(pos_mask_gt, (2, 0, 1))

# %%
img_test = 255*np.ones((90,302,3), dtype=np.int8)
_, _h, _w = mask_p.shape

for i in range(pos_prior_box.shape[0]):
    box = pos_prior_box[i]*[_h, _w, _h, _w]
    box = np.round(box).astype(int)
    image = cv2.rectangle(img_test, (box[1], box[0]), (box[3], box[2]), (0, 255, 0), 2)
plt.imshow(image)

# %%
for i in range(mask_p.shape[0]):
    plt.imshow(mask_p[i])
    plt.show()

# %%
for i in range(mask_p_crop.shape[0]):
    plt.imshow(mask_p_crop[i])
    plt.show()

# %%
for i in range(pos_mask_gt.shape[0]):
    plt.imshow(pos_mask_gt[i])
    plt.show()

# %% [markdown]
# # semantic_segmentation check

# %%
def _loss_semantic_segmentation(pred_seg, mask_gt, classes):
    batch_size, mask_h, mask_w, num_classes = tf.shape(pred_seg)
    loss_s = 0

    for i in range(batch_size):
        cur_segment = pred_seg[i]
        cur_class_gt = classes[i]
        masks = mask_gt[i]

        masks = tf.expand_dims(masks, axis=-1)
        masks = tf.image.resize(masks, [mask_h, mask_w], method=tf.image.ResizeMethod.BILINEAR)
        masks = tf.cast(masks + 0.5, tf.int64)
        masks = tf.squeeze(tf.cast(masks, tf.float32))

        segment_gt = tf.zeros_like(cur_segment) # [height, width, num_cls]
        segment_gt = tf.transpose(segment_gt, perm=(2, 0, 1))

        obj_cls = tf.expand_dims(cur_class_gt, axis=-1)
        segment_gt = tf.tensor_scatter_nd_max(segment_gt, indices=obj_cls, updates=masks)
        segment_gt = tf.transpose(segment_gt, perm=(1, 2, 0))

        loss_s += tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(segment_gt, cur_segment))

    return loss_s / mask_h / mask_w

# %%
masks=np.load('../masks.npy',allow_pickle=True)
segment_gt=np.load('../segment_gt.npy',allow_pickle=True)
obj_cls=np.load('../obj_cls.npy',allow_pickle=True)
cur_segment=np.load('../cur_segment.npy',allow_pickle=True)

segment_gt = np.transpose(segment_gt, (2, 0, 1))
cur_segment = np.transpose(cur_segment, (2, 0, 1))

# %%
for i in range(obj_cls.shape[0]):
    plt.imshow(masks[i])
    plt.show()

# %%
for i in range(segment_gt.shape[0]):
    plt.imshow(segment_gt[i])
    plt.show()

# %%
for i in range(cur_segment.shape[0]):
    plt.imshow(cur_segment[i])
    plt.show()
